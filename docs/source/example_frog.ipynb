# %% [markdown]
# # FROG

# %% [markdown]
# ### Simulate FROG-Traces

# %% [markdown]
# ## Run Classical Solvers

# %% [markdown]
# ### Vanilla

# %% [markdown]
# ### LSGPA

# %% [markdown]
# ### C-PCGPA

# %% [markdown]
# ### Generalized Projection

# %% [markdown]
# ### Ptychographic Iterative Engine

# %% [markdown]
# ### COPRA

# %% [markdown]
# ## Run General Optimization

# %% [markdown]
# ### Differential Evolution

# %% [markdown]
# ### Evosax

# %% [markdown]
# ### LSF

# %% [markdown]
# ### AutoDiff
