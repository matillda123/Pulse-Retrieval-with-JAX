# %% [markdown]
# # Overview Methods

# %% [markdown]
# ## FROG

# %% [markdown]
# ## Chirp-Scan

# %% [markdown]
# ## Time-Domain-Ptchography

# %% [markdown]
# ## 2D-SI

# %% [markdown]
# ## VAMPIRE
